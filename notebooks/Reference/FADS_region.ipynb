# %% [markdown]
# # Region reference files

# %% [markdown]
# [1000 Genomes phase 3](https://www.cog-genomics.org/plink/2.0/resources#phase3_1kg) from plink2 resources.

# %%
from pyprojroot.here import here

# %% [markdown]
# Extract specified region for each SuperPop. Use bash magic command and pass directory location as an argument to the script.

# %%
# %%bash -s {here()}
# here=$1
#
# for cluster in AFR AMR EAS EUR SAS; do
#     plink2 \
#         --pfile ${here}/data/reference/1000G/all_hg38 'vzs' \
#         --keep-if "SuperPop = $cluster" \
#         --chr 11 \
#         --from-bp 61000000 \
#         --to-bp 63000000 \
#         --max-alleles 2 \
#         --make-bed \
#         --out ${here}/data/processed/reference/all_hg38_${cluster}_chr11_61000000-63000000
# done
# Out:
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/madams23/Projects/cvd-mh-loci/data/processed/reference/all_hg38_AFR_chr11_61000000-63000000.log.
# Options in effect:
#   --chr 11
#   --from-bp 61000000
#   --keep-if SuperPop = AFR
#   --make-bed
#   --max-alleles 2
#   --out /home/madams23/Projects/cvd-mh-loci/data/processed/reference/all_hg38_AFR_chr11_61000000-63000000
#   --pfile /home/madams23/Projects/cvd-mh-loci/data/reference/1000G/all_hg38 vzs
#   --to-bp 63000000
#
# Start time: Fri Jul 25 11:21:08 2025
# 32012 MiB RAM detected, ~16993 available; reserving 16006 MiB for main
# workspace.
# Using up to 8 compute threads.
# 3202 samples (1603 females, 1599 males; 2583 founders) loaded from
# /home/madams23/Projects/cvd-mh-loci/data/reference/1000G/all_hg38.psam.
# Note: 2585 nonstandard chromosome codes present.
# ...

# %%
# %%bash -s {here()}
# here=$1
#
# for cluster in AFR AMR EAS EUR SAS; do
#     plink2 \
#         --pfile ${here}/data/reference/1000G/all_phase3 'vzs' \
#         --keep-if "SuperPop = $cluster" \
#         --chr 11 \
#         --from-bp 61000000 \
#         --to-bp 63000000 \
#         --max-alleles 2 \
#         --make-bed \
#         --out ${here}/data/processed/reference/all_h19_${cluster}_chr11_61000000-63000000
# done
# Out:
# PLINK v2.0.0-a.6.9LM 64-bit Intel (29 Jan 2025)    cog-genomics.org/plink/2.0/
# (C) 2005-2025 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/madams23/Projects/cvd-mh-loci/data/processed/reference/all_h19_AFR_chr11_61000000-63000000.log.
# Options in effect:
#   --chr 11
#   --from-bp 61000000
#   --keep-if SuperPop = AFR
#   --make-bed
#   --max-alleles 2
#   --out /home/madams23/Projects/cvd-mh-loci/data/processed/reference/all_h19_AFR_chr11_61000000-63000000
#   --pfile /home/madams23/Projects/cvd-mh-loci/data/reference/1000G/all_phase3 vzs
#   --to-bp 63000000
#
# Start time: Mon Aug 25 14:36:04 2025
# 32012 MiB RAM detected, ~19259 available; reserving 16006 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2504 samples (1271 females, 1233 males; 2497 founders) loaded from
# /home/madams23/Projects/cvd-mh-loci/data/reference/1000G/all_phase3.psam.
# 4024959 out of 84805772 variants loaded from
# ...
